# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import xlrd

pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 100)
# Out:
# /Users/khanfazil/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# Importing Annual Groundwater data (excel files) for both the states. Cleaning it (changing column names, adding a column for year, and dropping top two rows which were just random headers). Exporting a CSV for each year.

# %% [markdown]
# # 1996

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_1996.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <199601> to <199612>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 1996
df.to_csv("GWStation-96.csv", index=False)

# %% [markdown]
# # 1997

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_1997.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <199701> to <199712>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 1997
df.to_csv("GWStation-97.csv", index=False)

# %% [markdown]
# # 1998

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_1998.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <199801> to <199812>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 1998
df.to_csv("GWStation-98.csv", index=False)

# %% [markdown]
# # 1999

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_1999.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <199901> to <199912>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 1999
df.to_csv("GWStation-99.csv", index=False)

# %% [markdown]
# # 2000

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2000.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200001> to <200012>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2000
df.to_csv("GWStation-00.csv", index=False)

# %% [markdown]
# # 2001

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2001.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200101> to <200112>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2001
df.to_csv("GWStation-01.csv", index=False)

# %% [markdown]
# # 2002

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2002.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200201> to <200212>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2002
df.to_csv("GWStation-02.csv", index=False)

# %% [markdown]
# # 2003

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2003.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200301> to <200312>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2003
df.to_csv("GWStation-03.csv", index=False)

# %% [markdown]
# # 2004

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2004.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200401> to <200412>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2004
df.to_csv("GWStation-04.csv", index=False)

# %% [markdown]
# # 2005

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2005.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200501> to <200512>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2005
df.to_csv("GWStation-05.csv", index=False)

# %% [markdown]
# # 2006

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2006.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200601> to <200612>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2006
df.to_csv("GWStation-06.csv", index=False)

# %% [markdown]
# # 2007

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2007.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200701> to <200712>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2007
df.to_csv("GWStation-07.csv", index=False)

# %% [markdown]
# # 2008

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2008.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200801> to <200812>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2008
df.to_csv("GWStation-08.csv", index=False)

# %% [markdown]
# # 2009

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2009.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <200901> to <200912>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2009
df.to_csv("GWStation-09.csv", index=False)

# %% [markdown]
# # 2010

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2010.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201001> to <201012>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2010
df.to_csv("GWStation-10.csv", index=False)

# %% [markdown]
# # 2011

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2011.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201101> to <201112>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2011
df.to_csv("GWStation-11.csv", index=False)

# %% [markdown]
# # 2012

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2012.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201201> to <201212>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2012
df.to_csv("GWStation-12.csv", index=False)

# %% [markdown]
# # 2013

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2013.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201301> to <201312>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2013
df.to_csv("GWStation-13.csv", index=False)

# %% [markdown]
# # 2014

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2014.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201401> to <201412>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2014
df.to_csv("GWStation-14.csv", index=False)

# %% [markdown]
# # 2015

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2015.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201501> to <201512>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2015
df.to_csv("GWStation-15.csv", index=False)

# %% [markdown]
# # 2016

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2016.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201601> to <201612>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2016
df.to_csv("GWStation-16.csv", index=False)

# %% [markdown]
# # 2017

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2017.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201701> to <201712>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2017
df.to_csv("GWStation-17.csv", index=False)

# %% [markdown]
# # 2018

# %%
df = pd.read_excel("/Users/khanfazil/Desktop/master's_project/GW_Levels_Station_Haryana/Jan-Dec_2018.xls")
df = df.replace("-", "")
df = df.rename(columns={
    "GROUNDWATERWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <201801> to <201812>)": "STATE",
    "Unnamed: 1": "DISTRICT",
    "Unnamed: 2": "STATION",
    "Unnamed: 3": "LATITUDE",
    "Unnamed: 4": "LONGITUDE",
    "Unnamed: 5": "STATION_TYPE",
    "Unnamed: 6": "JAN (Level m)",
    "Unnamed: 7": "FEB (Level m)",
    "Unnamed: 8": "MAR (Level m)",
    "Unnamed: 9": "APR (Level m)",
    "Unnamed: 10": "MAY (Level m)",
    "Unnamed: 11": "JUN (Level m)",
    "Unnamed: 12": "JUL (Level m)",
    "Unnamed: 13": "AUG (Level m)",
    "Unnamed: 14": "SEP (Level m)",
    "Unnamed: 15": "OCT (Level m)",
    "Unnamed: 16": "NOV (Level m)",
    "Unnamed: 17": "DEC (Level m)",
})
df = df.drop([0,1])
df['YEAR'] = 2018
df.to_csv("GWStation-18.csv", index=False)

# %% [markdown]
# # Concatenating All the csvs

# %%
csv_file_list = ['GWStation-96.csv', 'GWStation-97.csv', 'GWStation-98.csv', 'GWStation-99.csv',
                 'GWStation-00.csv', 'GWStation-01.csv', 'GWStation-02.csv', 'GWStation-03.csv',
                 'GWStation-04.csv', 'GWStation-05.csv', 'GWStation-06.csv', 'GWStation-07.csv',
                 'GWStation-08.csv', 'GWStation-09.csv', 'GWStation-10.csv', 'GWStation-11.csv',
                 'GWStation-12.csv', 'GWStation-13.csv', 'GWStation-14.csv', 'GWStation-15.csv',
                 'GWStation-16.csv', 'GWStation-17.csv', 'GWStation-18.csv']

list_of_dataframes = []
for filename in csv_file_list:
    list_of_dataframes.append(pd.read_csv(filename))

df = pd.concat(list_of_dataframes)

# %%
df = df[['STATE', 'DISTRICT', 'STATION', 'LATITUDE', 'LONGITUDE', 'STATION_TYPE', 'MAY (Level m)', 'AUG (Level m)', 'YEAR']]

# %%
df.to_csv("stationsHaryana.csv", index=False)

# %%
df[df.YEAR == 2018]
# Out:
#         STATE   DISTRICT           STATION   LATITUDE  LONGITUDE STATION_TYPE  \
# 0     HARYANA      SIRSA      Berwalakhurd  29.452778  74.568056       Manual
# 1     HARYANA      MEWAT   Pipaka-Shashola  28.226389  77.029167       Manual
# 2     HARYANA  FARIDABAD     Manjhawali-DW  28.369444  77.477500       Manual
# 3     HARYANA     PALWAL           Achheja  28.045833  77.466667       Manual
# 4     HARYANA  FATEHABAD  Khajuri Jatti-Pz  29.475556  75.611111       Manual
# ...       ...        ...               ...        ...        ...          ...
# 1456  HARYANA    BHIWANI          Behal-Pz  28.634167  75.561111       Manual
# 1457  HARYANA    SONIPAT           Kathura  29.108333  76.583333       Manual
# 1458  HARYANA    GURGAON          Gurgaon1  28.463889  77.037500       Manual
# 1459  HARYANA    JHAJJAR            Nahar1  28.473611  76.400000       Manual
# 1460  HARYANA     KARNAL       Sambli-Pz-M  29.758333  76.800000       Manual
#
#       MAY (Level m)  AUG (Level m)  YEAR
# 0             10.50            NaN  2018
# 1               NaN            NaN  2018
# 2             14.38            NaN  2018
# 3               NaN            NaN  2018
# 4               NaN            NaN  2018
# ...             ...            ...   ...
# 1456            NaN            NaN  2018
# 1457           3.27            NaN  2018
# 1458          47.65            NaN  2018
# 1459          30.60            NaN  2018
# 1460          21.90            NaN  2018
#
# [1461 rows x 9 columns]

# %%
import geopandas as gpd

# %%
df.head()
# Out:
#      STATE   DISTRICT           STATION   LATITUDE  LONGITUDE STATION_TYPE  \
# 0  HARYANA      SIRSA      Berwalakhurd  29.452778  74.568056       Manual
# 1  HARYANA      MEWAT   Pipaka-Shashola  28.226389  77.029167       Manual
# 2  HARYANA  FARIDABAD     Manjhawali-DW  28.369444  77.477500       Manual
# 3  HARYANA     PALWAL           Achheja  28.045833  77.466667       Manual
# 4  HARYANA  FATEHABAD  Khajuri Jatti-Pz  29.475556  75.611111       Manual
#
#    MAY (Level m)  AUG (Level m)  YEAR
# 0           2.55            2.4  1996
# 1            NaN            NaN  1996
# 2            NaN            NaN  1996
# 3            NaN            NaN  1996
# 4            NaN            NaN  1996

# %% [markdown]
# Converting into a GeoJSON

# %%
dfGeo = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.LONGITUDE, df.LATITUDE))

# %%
dfGeo.to_csv("HaryanaGWSationsPoints.csv", index=False)

# %% [markdown]
# Taking just 1996 and 2018

# %%
dfGeo96 = dfGeo[dfGeo.YEAR == 1996]
dfGeo18 = dfGeo[dfGeo.YEAR == 2018]

# %% [markdown]
# Dropping Null values

# %%
dfGeo96 = dfGeo96.dropna(subset = ['MAY (Level m)'])
dfGeo18 = dfGeo18.dropna(subset = ['MAY (Level m)'])

# %%
print(dfGeo18['MAY (Level m)'].sort_values(ascending=False).head())
# Out:
# 100     81.83
# 1385    71.60
# 600     69.40
# 538     66.91
# 356     64.38
# Name: MAY (Level m), dtype: float64

# %% [markdown]
# There was mismatch in the number of stations between 1996 and 2018. Experts said it was normal.

# %%
dfGeo96['STATE'].value_counts()
# Out:
# HARYANA    383
# Name: STATE, dtype: int64

# %%
dfGeo18['STATE'].value_counts()
# Out:
# HARYANA    771
# Name: STATE, dtype: int64

# %%
# dfGeo96[dfGeo96['DISTRICT'].str.contains("BHIWANI")]

# %%
# dfGeo18['MAY (Level m)'].sort_values(ascending=False)

# %%
# dfGeo18[dfGeo18['MAY (Level m)'] == 81.83]

# %%
dfGeo18[~dfGeo18.LATITUDE.isin(dfGeo96.LATITUDE)]
# Out:
#         STATE     DISTRICT          STATION   LATITUDE  LONGITUDE  \
# 2     HARYANA    FARIDABAD    Manjhawali-DW  28.369444  77.477500
# 5     HARYANA  KURUKSHETRA       Kaulapur S  30.025000  76.895833
# 7     HARYANA      BHIWANI        Runhat-DW  29.000556  75.938889
# 11    HARYANA       KARNAL        Nisang-Pz  29.694444  76.754167
# 12    HARYANA        MEWAT  Rangla Dhani-Pz  28.227778  76.870833
# ...       ...          ...              ...        ...        ...
# 1452  HARYANA       REWARI        Bhakli-DW  28.416667  76.477778
# 1453  HARYANA      SONIPAT         Rasoi Pz  28.902778  77.113889
# 1458  HARYANA      GURGAON         Gurgaon1  28.463889  77.037500
# 1459  HARYANA      JHAJJAR           Nahar1  28.473611  76.400000
# 1460  HARYANA       KARNAL      Sambli-Pz-M  29.758333  76.800000
#
#      STATION_TYPE  MAY (Level m)  AUG (Level m)  YEAR  \
# 2          Manual          14.38            NaN  2018
# 5          Manual          38.80            NaN  2018
# 7          Manual           5.70            NaN  2018
# 11         Manual          35.98            NaN  2018
# 12         Manual          24.57            NaN  2018
# ...           ...            ...            ...   ...
# 1452       Manual          12.50            NaN  2018
# 1453       Manual          19.60          19.96  2018
# 1458       Manual          47.65            NaN  2018
# 1459       Manual          30.60            NaN  2018
# 1460       Manual          21.90            NaN  2018
#
#                        geometry
# 2     POINT (77.47750 28.36944)
# 5     POINT (76.89583 30.02500)
# 7     POINT (75.93889 29.00056)
# 11    POINT (76.75417 29.69444)
# 12    POINT (76.87083 28.22778)
# ...                         ...
# 1452  POINT (76.47778 28.41667)
# 1453  POINT (77.11389 28.90278)
# 1458  POINT (77.03750 28.46389)
# 1459  POINT (76.40000 28.47361)
# 1460  POINT (76.80000 29.75833)
#
# [545 rows x 10 columns]

# %%
import altair as alt

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
map96 = alt.Chart(dfGeo96).mark_geoshape().encode(
    color=alt.Color('MAY (Level m):Q', title='MAY (Level m)', scale=alt.Scale(scheme='inferno', domain=[55,0])),
    tooltip=['MAY (Level m):Q','STATE','DISTRICT','STATION', 'YEAR'],
).properties(
    title='Station-wise Groudnwater Depth 1996',
    width=500,
    height=500
)

map18 = alt.Chart(dfGeo18).mark_geoshape().encode(
    color=alt.Color('MAY (Level m):Q', title='MAY (Level m)', scale=alt.Scale(scheme='inferno', domain=[55,0])),
    tooltip=['MAY (Level m):Q','STATE','DISTRICT','STATION', 'YEAR'],
).properties(
    title='Station-wise Groudnwater Depth 2018, Haryana',
    width=500,
    height=500
)

map18
# Out:
# alt.Chart(...)

# %%
map18
# Out:
# alt.Chart(...)

# %%
india = gpd.read_file('https://github.com/fazilkhan/storytellingWithData/blob/main/INDIASHAPEFILE.zip?raw=true')

# %%
PunjabHaryana = india[(india.nam == "PUNJAB") | (india.nam == "HARYANA")]
